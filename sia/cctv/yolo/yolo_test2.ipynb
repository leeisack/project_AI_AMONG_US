# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# 웹캠 신호 받기
VideoSignal = cv2.VideoCapture(0)

# 동영상
# VideoSignal = cv2.VideoCapture('test2.mp4')

# YOLO 가중치 파일과 CFG 파일 로드
YOLO_net = cv2.dnn.readNet("yolov3.weights","yolov3.cfg")

# YOLO NETWORK 재구성
classes = []
with open("coco.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = YOLO_net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in YOLO_net.getUnconnectedOutLayers()]

while True:
    # 웹캠 프레임
    ret, frame = VideoSignal.read()
    h, w, c = frame.shape

    # YOLO 입력
    blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
    YOLO_net.setInput(blob)
    outs = YOLO_net.forward(output_layers)

    class_ids = []
    confidences = []
    boxes = []

    for out in outs:

        for detection in out:

            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            if confidence > 0.5:
                # Object detected
                center_x = int(detection[0] * w)
                center_y = int(detection[1] * h)
                dw = int(detection[2] * w)
                dh = int(detection[3] * h)
                # Rectangle coordinate
                x = int(center_x - dw / 2)
                y = int(center_y - dh / 2)
                boxes.append([x, y, dw, dh])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.45, 0.4)


    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            label = str(classes[class_ids[i]])
            
            # 요기서부터 내코드
            import timeit
            if label == 'person':
                start = timeit.timeit()
                end = timeit.timeit()
                print(end-start)
                
            # 요기까지 내코드
            score = confidences[i]

            # 경계상자와 클래스 정보 이미지에 입력
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 5)
            cv2.putText(frame, label, (x, y - 20), cv2.FONT_ITALIC, 0.5, 
            (255, 255, 255), 1)

    cv2.imshow("YOLOv3", frame)

    if cv2.waitKey(100) > 0:
        break
cv2.destroyAllWindows()
# Out:
# 3.009999954883824e-05
# -0.0008453999998891959
# -0.0008436000002802757
# 0.0005185999998502666
# 0.000650599999971746
# -0.0010032000000137486
# 0.0008827999999994063
# -0.0010946000002149958
# -0.0007009000000834931
# 4.599999965648749e-05
# -0.0014717999997628795
# 0.000830599999972037
# -0.001306299999669136
# -0.0004399999997986015
# 0.0011305999996693572
# 0.0005620000001727021
# -7.519999962823931e-05
# 0.0024951999998847896
# -0.00017450000041208114
# -0.00038600000016231206
# 0.0004683000001932669
# 0.0001369999995404214
# -0.0010308999999324442
# -0.00015320000011342927
# -0.0006486000002041692
# -0.0017372000002069399
# -0.0012037999995300197
# 0.002512600000045495
# 0.0006376000001182547
# -0.0008245999997598119
# -0.001313300000219897
# -0.00012519999972937512
# 0.0015782999998918967
# 0.0003744999999071297
# -0.0009619000002203393
# -0.0017749999997249688
# -0.0010516000002098735
# 9.390000013809185e-05
# -0.002230799999779265
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-549fbb518bed> in <module>
#      27     blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
#      28     YOLO_net.setInput(blob)
# ---> 29     outs = YOLO_net.forward(output_layers)
#      30
#      31     class_ids = []
#
# KeyboardInterrupt:
